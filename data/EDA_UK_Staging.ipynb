# %%
import numpy as np
import pandas as pd
import seaborn as sns
import glob as glob

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Reading individual csv files and concat them in one DataFrame

# %%
acc2017 = pd.read_csv('C:/BIA/ETL/UK_Staging/accidents/dft-road-casualty-statistics-accident-2017.csv', low_memory=False)
acc2017
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 129977  2017984121017           2017          984121017
# 129978  2017984121217           2017          984121217
# 129979  2017984121717           2017          984121717
# 129980  2017984122317           2017          984122317
# 129981  2017984122617           2017          984122617
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
acc2018 = pd.read_csv('C:/BIA/ETL/UK_Staging/accidents/dft-road-casualty-statistics-accident-2018.csv',low_memory=False)
acc2018
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2018010080971           2018          010080971
# 1       2018010080973           2018          010080973
# 2       2018010080974           2018          010080974
# 3       2018010080981           2018          010080981
# 4       2018010080982           2018          010080982
# ...               ...            ...                ...
# 122630  2018984115718           2018          984115718
# 122631  2018984115918           2018          984115918
# 122632  2018984116018           2018          984116018
# 122633  2018984116318           2018          984116318
# 122634  2018984116418           2018          984116418
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    529150.0                182270.0  -0.139737  51.524587
# 1                    542020.0                184290.0   0.046471  51.539651
# ...

# %%
acc2019 = pd.read_csv('C:/BIA/ETL/UK_Staging/accidents/dft-road-casualty-statistics-accident-2019.csv',low_memory=False)
acc2019
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2019010128300           2019          010128300
# 1       2019010152270           2019          010152270
# 2       2019010155191           2019          010155191
# 3       2019010155192           2019          010155192
# 4       2019010155194           2019          010155194
# ...               ...            ...                ...
# 117531  2019984106919           2019          984106919
# 117532  2019984107019           2019          984107019
# 117533  2019984107219           2019          984107219
# 117534  2019984107419           2019          984107419
# 117535  201998QC01004           2019          98QC01004
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    528218.0                180407.0  -0.153842  51.508057
# 1                    530219.0                172463.0  -0.127949  51.436208
# ...

# %%
acc2020 = pd.read_csv('C:/BIA/ETL/UK_Staging/accidents/dft-road-casualty-statistics-accident-2020.csv', low_memory=False)
acc2020
# Out:
#       accident_index  accident_year accident_reference  location_easting_osgr  \
# 0      2020010219808           2020          010219808               521389.0
# 1      2020010220496           2020          010220496               529337.0
# 2      2020010228005           2020          010228005               526432.0
# 3      2020010228006           2020          010228006               538676.0
# 4      2020010228011           2020          010228011               529324.0
# ...              ...            ...                ...                    ...
# 91194  2020991027064           2020          991027064               343034.0
# 91195  2020991029573           2020          991029573               257963.0
# 91196  2020991030297           2020          991030297               383664.0
# 91197  2020991030900           2020          991030900               277161.0
# 91198  2020991032575           2020          991032575               240402.0
#
# ...

# %%
acc2021 = pd.read_csv('C:/BIA/ETL/UK_Staging/accidents/dft-road-casualty-statistics-accident-2021.csv', low_memory=False)
acc2021
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2021010287148           2021          010287148
# 1       2021010287149           2021          010287149
# 2       2021010287151           2021          010287151
# 3       2021010287155           2021          010287155
# 4       2021010287157           2021          010287157
# ...               ...            ...                ...
# 101082  2021991196247           2021          991196247
# 101083  2021991196607           2021          991196607
# 101084  2021991197944           2021          991197944
# 101085  2021991200639           2021          991200639
# 101086  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    521508.0                193079.0  -0.246102  51.623425
# 1                    535379.0                180783.0  -0.050574  51.509767
# ...

# %%
stg_accidents = pd.concat([acc2017, acc2018, acc2019, acc2020, acc2021] ,ignore_index=True)
stg_accidents
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 562434  2021991196247           2021          991196247
# 562435  2021991196607           2021          991196607
# 562436  2021991197944           2021          991197944
# 562437  2021991200639           2021          991200639
# 562438  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
stg_accidents.to_csv('c:/BIA/ETL/UK_Staging/EDA/stg_accidents.csv')

# %%
stg_accidents.isna().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          133
# location_northing_osgr                         133
# longitude                                      143
# latitude                                       143
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...

# %%
stg_accidents.groupby(['accident_year']).count()
# Out:
#                accident_index  accident_reference  location_easting_osgr  \
# accident_year
# 2017                   129982              129982                 129963
# 2018                   122635              122635                 122580
# 2019                   117536              117536                 117508
# 2020                    91199               91199                  91185
# 2021                   101087              101087                 101070
#
#                location_northing_osgr  longitude  latitude  police_force  \
# accident_year
# 2017                           129963     129953    129953        129982
# 2018                           122580     122580    122580        122635
# 2019                           117508     117508    117508        117536
# 2020                            91185      91185     91185         91199
# 2021                           101070     101070    101070        101087
#
# ...

# %% [markdown]
# ## Reading multiple files to create a single DataFrame for Accidents

# %%
files = glob.glob('C:/BIA/ETL/UK_Staging/accidents/dft-road-casualty-statistics-accident-*.csv')
files
# Out:
# ['C:/BIA/ETL/UK_Staging/accidents\\dft-road-casualty-statistics-accident-2017.csv',
#  'C:/BIA/ETL/UK_Staging/accidents\\dft-road-casualty-statistics-accident-2018.csv',
#  'C:/BIA/ETL/UK_Staging/accidents\\dft-road-casualty-statistics-accident-2019.csv',
#  'C:/BIA/ETL/UK_Staging/accidents\\dft-road-casualty-statistics-accident-2020.csv',
#  'C:/BIA/ETL/UK_Staging/accidents\\dft-road-casualty-statistics-accident-2021.csv']

# %%
# Reading multiple files to create a single DataFrame
accidents = pd.concat([pd.read_csv(f, low_memory=False) for f in files], ignore_index=True)

# %%
accidents
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 562434  2021991196247           2021          991196247
# 562435  2021991196607           2021          991196607
# 562436  2021991197944           2021          991197944
# 562437  2021991200639           2021          991200639
# 562438  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
accidents['local_authority_highway'].unique()
# Out:
# array(['E09000010', 'E09000033', 'E09000030', 'E09000012', 'E09000027',
#        'E09000017', 'E09000003', 'E09000022', 'E09000014', 'E09000009',
#        'E09000028', 'E09000007', 'E09000016', 'E09000032', 'E09000013',
#        'EHEATHROW', 'E09000026', 'E09000002', 'E09000011', 'E09000024',
#        'E09000031', 'E09000006', 'E09000029', 'E09000005', 'E09000019',
#        'E09000008', 'E09000004', 'E09000018', 'E09000025', 'E09000021',
#        'E09000020', 'E09000015', 'E09000023', 'E09000001', 'E10000006',
#        'E10000017', 'E06000008', 'E06000009', 'E08000015', 'E08000012',
#        'E08000014', 'E08000011', 'E08000013', 'E08000010', 'E08000007',
#        'E08000009', 'E08000003', 'E08000006', 'E08000008', 'E08000001',
#        'E08000002', 'E08000005', 'E08000004', 'E06000049', 'E06000007',
#        'E06000050', 'E06000006', 'E08000022', 'E08000021', 'E08000020',
#        'E08000023', 'E06000048', 'E08000024', 'E06000005', 'E06000047',
# ...

# %%
accidents[(accidents['local_authority_highway'] == '-1') & (accidents['accident_year'] == 2018)]
# Out:
#        accident_index  accident_year accident_reference  \
# 204608  2018370256350           2018          370256350
# 204610  2018370258201           2018          370258201
# 204612  2018370260290           2018          370260290
# 204615  2018370260720           2018          370260720
# 204617  2018370260794           2018          370260794
# ...               ...            ...                ...
# 206065  2018370828800           2018          370828800
# 206066  2018370829955           2018          370829955
# 206067  2018370833307           2018          370833307
# 206068  2018370835221           2018          370835221
# 206069  2018370841831           2018          370841831
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 204608               589233.0                257460.0   0.766560  52.182936
# 204610               630021.0                234111.0   1.346445  51.957890
# ...

# %%
accidents[(accidents['accident_year'] == 2018) & (accidents['police_force'] == 37)]
# Out:
#        accident_index  accident_year accident_reference  \
# 204607  2018370256025           2018          370256025
# 204608  2018370256350           2018          370256350
# 204609  2018370258121           2018          370258121
# 204610  2018370258201           2018          370258201
# 204611  2018370259744           2018          370259744
# ...               ...            ...                ...
# 206065  2018370828800           2018          370828800
# 206066  2018370829955           2018          370829955
# 206067  2018370833307           2018          370833307
# 206068  2018370835221           2018          370835221
# 206069  2018370841831           2018          370841831
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 204607               603468.0                243203.0   0.965972  52.049866
# 204608               589233.0                257460.0   0.766560  52.182936
# ...

# %%
accidents.isna().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          133
# location_northing_osgr                         133
# longitude                                      143
# latitude                                       143
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...

# %%
accidents.groupby(['accident_year'])['number_of_casualties'].sum()
# Out:
# accident_year
# 2017    170993
# 2018    160597
# 2019    153158
# 2020    115584
# 2021    128209
# Name: number_of_casualties, dtype: int64

# %%
(accidents['number_of_casualties']==0).sum()
# Out:
# 0

# %%
accidents['road_type'].unique()
# Out:
# array([6, 1, 3, 9, 7, 2], dtype=int64)

# %%
accidents
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 562434  2021991196247           2021          991196247
# 562435  2021991196607           2021          991196607
# 562436  2021991197944           2021          991197944
# 562437  2021991200639           2021          991200639
# 562438  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
accidents
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 562434  2021991196247           2021          991196247
# 562435  2021991196607           2021          991196607
# 562436  2021991197944           2021          991197944
# 562437  2021991200639           2021          991200639
# 562438  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
accidents.groupby(['first_road_class'])['number_of_casualties'].sum()
# Out:
# first_road_class
# 1     28619
# 2      2315
# 3    329060
# 4     88595
# 5     37655
# 6    242297
# Name: number_of_casualties, dtype: int64

# %%
accidents2018 = accidents[(accidents['accident_year'] == 2018)]# & (accidents['urban_or_rural_area'] == -1)]
accidents2018['number_of_casualties'].sum()
# Out:
# 160597

# %%
accidents2018['urban_or_rural_area'].unique()
# Out:
# array([ 1,  2,  3, -1], dtype=int64)

# %%
accidents2018 = accidents[(accidents['accident_year'] == 2018)] # & (accidents['urban_or_rural_area'] == -1)]
accidents2018['number_of_casualties'].sum()
# Out:
# 160597

# %%
accidents2018.groupby(['urban_or_rural_area'])['number_of_casualties'].sum()
# Out:
# urban_or_rural_area
# -1         4
#  1    102256
#  2     58261
#  3        76
# Name: number_of_casualties, dtype: int64

# %% [markdown]
# ## ## Reading multiple files to create a single DataFrame for Casualty

# %%
files2 = glob.glob('C:/BIA/ETL/UK_Staging/casualties/dft-road-casualty-statistics-casualty-*.csv')
files2
casualties = pd.concat([pd.read_csv(f, low_memory=False) for f in files2], ignore_index=True)
casualties
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 0         2.01701E+12           2017           10001708                  1
# 1         2.01701E+12           2017           10001708                  2
# 2         2.01701E+12           2017           10001708                  2
# 3         2.01701E+12           2017           10009342                  1
# 4         2.01701E+12           2017           10009344                  3
# ...               ...            ...                ...                ...
# 728536  2021991196607           2021          991196607                  1
# 728537  2021991196607           2021          991196607                  2
# 728538  2021991197944           2021          991197944                  1
# 728539  2021991200639           2021          991200639                  1
# 728540  2021991201030           2021          991201030                  2
#
# ...

# %%
casualties[casualties['casualty_type'] == 22]
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 32527     2.01703E+12           2017           30162341                  1
# 32732     2.01703E+12           2017           30177525                  1
# 33224     2.01703E+12           2017           30206646                  2
# 33353     2.01703E+12           2017           30214491                  1
# 33951     2.01703E+12           2017           30265152                  2
# ...               ...            ...                ...                ...
# 723723  2021991019285           2021          991019285                  2
# 724590  2021991039404           2021          991039404                  1
# 724801  2021991044877           2021          991044877                  1
# 725761  2021991065543           2021          991065543                  1
# 727608  2021991106519           2021          991106519                  2
#
# ...

# %%
casualties['age_of_casualty'].unique()
# Out:
# array([ 18,  19,  33,  31,   3,  45,  14,  58,  27,  39,  48,  26,  47,
#         11,  15,  23,  60,  34,  44,  25,  50,  53,  13,  22,  24,  20,
#         37,  49,  59,  30,  17,  29,  69,  28,  16,  32,  41,   6,  36,
#          4,   7,   5,   8,  21,   9,  76,  73,  43,  54,  52,  74,  84,
#         65,  40,  88,  51,  63,  35,  55,  42,  61,  66,  86,  67,  46,
#         10,  72,  38,  12,  57,  56,   2,  90,  77,  71,  85,  91,  70,
#         62,  87,  80,  83,   0,  64,  89,  79,  82,  68,  -1,  94,   1,
#         78,  81,  93,  75,  92,  97,  96,  95,  98, 100,  99, 101, 102],
#       dtype=int64)

# %%
(casualties['casualty_type'] == 2021).sum()
# Out:
# 0

# %%
casualties.groupby('accident_year')['casualty_type'].unique()
# Out:
# accident_year
# 2017    [9, 2, 0, 3, 8, 1, 11, 4, 90, 19, 5, 10, 21, 2...
# 2018    [9, 8, 0, 1, 3, 2, 5, 11, 4, 19, 10, 90, 21, 2...
# 2019    [9, 1, 0, 8, 4, 3, 5, 11, 2, 22, 23, 19, 90, 9...
# 2020    [0, 9, 3, 8, 2, 11, 1, 19, 4, 5, 20, 90, 21, 2...
# 2021    [9, 0, 11, 5, 19, 3, 1, 90, 2, 8, 20, 4, 23, 1...
# Name: casualty_type, dtype: object

# %%
casualties['casualty_type'].unique()
# Out:
# array([ 9,  2,  0,  3,  8,  1, 11,  4, 90, 19,  5, 10, 21, 20, 16, 98, 23,
#        22, 17, 97, 18, 99, -1], dtype=int64)

# %%
casualties[(casualties['casualty_type'] == 99) & (casualties['accident_year']==2018)]
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 299013  201846T315787           2018          46T315787                  2
# 299014  201846T315787           2018          46T315787                  2
#
#         casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 299013                   1               1                2               48
# 299014                   2               2                2               -1
#
#         age_band_of_casualty  casualty_severity  pedestrian_location  \
# 299013                     8                  3                    0
# 299014                    -1                  3                    0
#
#         pedestrian_movement  car_passenger  bus_or_coach_passenger  \
# 299013                    0              0                       0
# 299014                    0              9                       0
#
#         pedestrian_road_maintenance_worker  casualty_type  \
# ...

# %%
casualties[(casualties['casualty_type'] == 90) & (casualties['accident_year'] == 2018)].count()
# Out:
# accident_index                        560
# accident_year                         560
# accident_reference                    560
# vehicle_reference                     560
# casualty_reference                    560
# casualty_class                        560
# sex_of_casualty                       560
# age_of_casualty                       560
# age_band_of_casualty                  560
# casualty_severity                     560
# pedestrian_location                   560
# pedestrian_movement                   560
# car_passenger                         560
# bus_or_coach_passenger                560
# pedestrian_road_maintenance_worker    560
# casualty_type                         560
# casualty_home_area_type               560
# casualty_imd_decile                   560
# lsoa_of_casualty                        0
# Unnamed: 18                             0
# dtype: int64

# %%
casualties
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 0         2.01701E+12           2017           10001708                  1
# 1         2.01701E+12           2017           10001708                  2
# 2         2.01701E+12           2017           10001708                  2
# 3         2.01701E+12           2017           10009342                  1
# 4         2.01701E+12           2017           10009344                  3
# ...               ...            ...                ...                ...
# 728536  2021991196607           2021          991196607                  1
# 728537  2021991196607           2021          991196607                  2
# 728538  2021991197944           2021          991197944                  1
# 728539  2021991200639           2021          991200639                  1
# 728540  2021991201030           2021          991201030                  2
#
# ...

# %%
accidents
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 562434  2021991196247           2021          991196247
# 562435  2021991196607           2021          991196607
# 562436  2021991197944           2021          991197944
# 562437  2021991200639           2021          991200639
# 562438  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
road_type = pd.DataFrame(accidents, columns=['accident_year' ,'first_road_class', 'urban_or_rural_area', 'number_of_casualties'])
road_type
# Out:
#         accident_year  first_road_class  urban_or_rural_area  \
# 0                2017                 3                    1
# 1                2017                 3                    1
# 2                2017                 3                    1
# 3                2017                 3                    1
# 4                2017                 3                    1
# ...               ...               ...                  ...
# 562434           2021                 6                    1
# 562435           2021                 3                    2
# 562436           2021                 4                    2
# 562437           2021                 3                    1
# 562438           2021                 3                    2
#
#         number_of_casualties
# 0                          3
# 1                          1
# 2                          1
# 3                          1
# 4                          1
# ...                      ...
# ...

# %%
road_type2018 = road_type[(road_type['accident_year'] == 2018)] 
road_type2018
# Out:
#         accident_year  first_road_class  urban_or_rural_area  \
# 129982           2018                 3                    1
# 129983           2018                 4                    1
# 129984           2018                 3                    1
# 129985           2018                 4                    1
# 129986           2018                 3                    1
# ...               ...               ...                  ...
# 252612           2018                 3                    2
# 252613           2018                 2                    1
# 252614           2018                 4                    2
# 252615           2018                 5                    2
# 252616           2018                 4                    2
#
#         number_of_casualties
# 129982                     2
# 129983                     1
# 129984                     1
# 129985                     1
# 129986                     2
# ...                      ...
# ...

# %%
road_type2018[(road_type2018['first_road_class'] == 1) | (road_type2018['first_road_class'] == 2)].sum()
# Out:
# accident_year           9214188
# first_road_class           4907
# urban_or_rural_area        8288
# number_of_casualties       7309
# dtype: int64

# %%
road_type2018[(road_type2018['first_road_class'] ==3) | (road_type2018['first_road_class'] == 4) 
              | (road_type2018['first_road_class'] == 5) | (road_type2018['first_road_class'] == 6)].sum()
# Out:
# accident_year           238263242
# first_road_class           512492
# urban_or_rural_area        154451
# number_of_casualties       153288
# dtype: int64

# %%
road_type2018[(road_type2018['first_road_class'] ==5)].sum()
# Out:
# accident_year           14136090
# first_road_class           35025
# urban_or_rural_area         8617
# number_of_casualties        8777
# dtype: int64

# %%
road_type2018[(road_type2018['urban_or_rural_area'] == 1)].sum()
# Out:
# accident_year           166652494
# first_road_class           366807
# urban_or_rural_area         82583
# number_of_casualties       102256
# dtype: int64

# %% [markdown]
# ## EDA on fact table

# %%
fact = pd.read_csv('C:/BIA/ETL/UK_Staging/Facts/f.UK_Road_Casualty.csv', low_memory=False)
fact
# Out:
#        accident_index  accident_year accident_reference  police_force  \
# 0       2021201082376           2021          201082376            20
# 1       2021201082383           2021          201082383            20
# 2       2021201082384           2021          201082384            20
# 3       2021201082407           2021          201082407            20
# 4       2021201082407           2021          201082407            20
# ...               ...            ...                ...           ...
# 728536  201731D027017           2017          31D027017            31
# 728537  2018460328922           2018          460328922            46
# 728538  2018460328922           2018          460328922            46
# 728539  2018010123866           2018          010123866             1
# 728540  2019010208894           2019          010208894             1
#
#         accident_severity  number_of_vehicles  number_of_casualties  \
# ...

# %%
fact.isna().sum()
# Out:
# accident_index             0
# accident_year              0
# accident_reference         0
# police_force               0
# accident_severity          0
# number_of_vehicles         0
# number_of_casualties       0
# acc_date                   0
# day_of_week                0
# time                       0
# local_authority_highway    0
# speed_limit                0
# casualty_class             0
# sex_of_casualty            0
# age_of_casualty            0
# age_band_of_casualty       0
# casualty_severity          0
# Road_type                  0
# Road_user_type             0
# dtype: int64

# %%
fact.groupby('sex_of_casualty').count()
# Out:
#                  accident_index  accident_year  accident_reference  \
# sex_of_casualty
# -1                         2546           2546                2546
#  1                       439624         439624              439624
#  2                       286347         286347              286347
#  9                           24             24                  24
#
#                  police_force  accident_severity  number_of_vehicles  \
# sex_of_casualty
# -1                       2546               2546                2546
#  1                     439624             439624              439624
#  2                     286347             286347              286347
#  9                         24                 24                  24
#
#                  number_of_casualties  acc_date  day_of_week    time  \
# sex_of_casualty
# -1                               2546      2546         2546    2546
#  1                             439624    439624       439624  439624
# ...

# %%
fact[(fact['sex_of_casualty']==9)]
# Out:
#        accident_index  accident_year accident_reference  police_force  \
# 19768   2021430151049           2021          430151049            43
# 243392  2018430197128           2018          430197128            43
# 317230  2020430055987           2020          430055987            43
# 317231  2020430055987           2020          430055987            43
# 318871  2020430173231           2020          430173231            43
# 318872  2020430173231           2020          430173231            43
# 319103  2020430204523           2020          430204523            43
# 364840  2018430300211           2018          430300211            43
# 364841  2018430300211           2018          430300211            43
# 408514  2018430092337           2018          430092337            43
# 409101  2018430362660           2018          430362660            43
# 499868  2019430011250           2019          430011250            43
# ...

# %%
fact['sex_of_casualty'].replace(to_replace= 9,value= -1, inplace=True)
fact
# Out:
#        accident_index  accident_year accident_reference  police_force  \
# 0       2021201082376           2021          201082376            20
# 1       2021201082383           2021          201082383            20
# 2       2021201082384           2021          201082384            20
# 3       2021201082407           2021          201082407            20
# 4       2021201082407           2021          201082407            20
# ...               ...            ...                ...           ...
# 728536  201731D027017           2017          31D027017            31
# 728537  2018460328922           2018          460328922            46
# 728538  2018460328922           2018          460328922            46
# 728539  2018010123866           2018          010123866             1
# 728540  2019010208894           2019          010208894             1
#
#         accident_severity  number_of_vehicles  number_of_casualties  \
# ...

# %%
# fact['sex_of_casualty'] = np.where(fact['sex_of_casualty']==9, -1, fact['sex_of_casualty'])
# fact['sex_of_casualty'].unique()
# Out:
# array([ 1,  2, -1], dtype=int64)

# %%
fact.groupby('sex_of_casualty').count()
# Out:
#                  accident_index  accident_year  accident_reference  \
# sex_of_casualty
# -1                         2570           2570                2570
#  1                       439624         439624              439624
#  2                       286347         286347              286347
#
#                  police_force  accident_severity  number_of_vehicles  \
# sex_of_casualty
# -1                       2570               2570                2570
#  1                     439624             439624              439624
#  2                     286347             286347              286347
#
#                  number_of_casualties  acc_date  day_of_week    time  \
# sex_of_casualty
# -1                               2570      2570         2570    2570
#  1                             439624    439624       439624  439624
#  2                             286347    286347       286347  286347
#
#                  local_authority_highway  speed_limit  casualty_class  \
# ...

# %%
fact['sex_of_casualty'].unique()
# Out:
# array([ 1,  2, -1], dtype=int64)

# %%
fact.shape
# Out:
# (728541, 19)

# %%
fact
# Out:
#        accident_index  accident_year accident_reference  police_force  \
# 0       2021201082376           2021          201082376            20
# 1       2021201082383           2021          201082383            20
# 2       2021201082384           2021          201082384            20
# 3       2021201082407           2021          201082407            20
# 4       2021201082407           2021          201082407            20
# ...               ...            ...                ...           ...
# 728536  201731D027017           2017          31D027017            31
# 728537  2018460328922           2018          460328922            46
# 728538  2018460328922           2018          460328922            46
# 728539  2018010123866           2018          010123866             1
# 728540  2019010208894           2019          010208894             1
#
#         accident_severity  number_of_vehicles  number_of_casualties  \
# ...

# %%
fact.to_csv('C:/BIA/ETL/UK_Staging/Facts/f.UK_Road_Casualty.csv')

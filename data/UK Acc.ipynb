# %%
import numpy as np
import pandas as pd
import seaborn as sns
import glob as glob

# %%
pd.set_option('display.max_columns',None)

# %% [markdown]
# ## Reading multiple files to create a single DataFrame for Casualties

# %%
files2 = glob.glob("rd - casualty-*.csv")
files2
# Out:
# ['rd - casualty-2017.csv',
#  'rd - casualty-2018.csv',
#  'rd - casualty-2019.csv',
#  'rd - casualty-2020.csv',
#  'rd - casualty-2021.csv']

# %%
casualties = pd.concat([pd.read_csv(f, low_memory=False) for f in files2], ignore_index=True)
casualties
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 0       2017010001708           2017          010001708                  1
# 1       2017010001708           2017          010001708                  2
# 2       2017010001708           2017          010001708                  2
# 3       2017010009342           2017          010009342                  1
# 4       2017010009344           2017          010009344                  3
# ...               ...            ...                ...                ...
# 728536  2021991196607           2021          991196607                  1
# 728537  2021991196607           2021          991196607                  2
# 728538  2021991197944           2021          991197944                  1
# 728539  2021991200639           2021          991200639                  1
# 728540  2021991201030           2021          991201030                  2
#
# ...

# %%
casualties['casualty_type'].unique()
# Out:
# array([ 9,  2,  0,  3,  8,  1, 11,  4, 90, 19,  5, 10, 21, 20, 16, 98, 23,
#        22, 17, 97, 18, 99, -1], dtype=int64)

# %%
casualties[casualties['casualty_type'] == 23]
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 32521   2017030161828           2017          030161828                  2
# 33211   2017030206114           2017          030206114                  2
# 63467   2017140162289           2017          140162289                  1
# 63864   2017140173092           2017          140173092                  1
# 63990   2017140177902           2017          140177902                  1
# ...               ...            ...                ...                ...
# 721666  2021622100664           2021          622100664                  1
# 721668  2021622100666           2021          622100666                  2
# 722422  202163A074121           2021          63A074121                  1
# 728036  2021991116831           2021          991116831                  1
# 728092  2021991118056           2021          991118056                  1
#
# ...

# %%
(casualties['casualty_type'] ==2018).sum()
# Out:
# 0

# %%
casualties.groupby('accident_year')['age_of_casualty'].unique()
# Out:
# accident_year
# 2017    [18, 19, 33, 31, 3, 45, 14, 58, 27, 39, 48, 26...
# 2018    [50, 48, 29, 40, 27, 43, 58, 69, 56, 60, 41, 3...
# 2019    [58, -1, 24, 21, 68, 47, 16, 20, 41, 25, 40, 2...
# 2020    [31, 2, 4, 23, 47, 32, 33, 25, 41, 50, 62, 37,...
# 2021    [19, 25, 21, 17, 27, 28, 20, 49, 37, 42, 30, 5...
# Name: age_of_casualty, dtype: object

# %%
casualties[('casualty_severity')].unique()
# Out:
# array([3, 2, 1], dtype=int64)

# %%
casualties[(casualties['casualty_type'] == 97) & (casualties['accident_year']==2018)]
# Out:
#        accident_index  accident_year accident_reference  vehicle_reference  \
# 201552  2018030275791           2018          030275791                  1
# 201667  2018030281739           2018          030281739                  1
# 201668  2018030281739           2018          030281739                  1
# 201669  2018030281739           2018          030281739                  1
# 201969  2018030300962           2018          030300962                  1
# ...               ...            ...                ...                ...
# 323413  201891SNH1836           2018          91SNH1836                  2
# 323530  201891SNM1896           2018          91SNM1896                  1
# 323763  201891SNP2807           2018          91SNP2807                  1
# 323783  201891SNP3661           2018          91SNP3661                  2
# 324099  2018921800406           2018          921800406                  2
#
# ...

# %%
casualties[(casualties['casualty_type'] == 97) & (casualties['accident_year'] == 2019)].count()
# Out:
# accident_index                        223
# accident_year                         223
# accident_reference                    223
# vehicle_reference                     223
# casualty_reference                    223
# casualty_class                        223
# sex_of_casualty                       223
# age_of_casualty                       223
# age_band_of_casualty                  223
# casualty_severity                     223
# pedestrian_location                   223
# pedestrian_movement                   223
# car_passenger                         223
# bus_or_coach_passenger                223
# pedestrian_road_maintenance_worker    223
# casualty_type                         223
# casualty_home_area_type               223
# casualty_imd_decile                   223
# lsoa_of_casualty                        0
# dtype: int64

# %% [markdown]
# ## Reading multiple files to create a single DataFrame for Accidents

# %%
files = glob.glob("rd - accident-*.csv")
files
# Out:
# ['rd - accident-2017.csv',
#  'rd - accident-2018.csv',
#  'rd - accident-2019.csv',
#  'rd - accident-2020.csv',
#  'rd - accident-2021.csv']

# %%
# Reading multiple files to create a single DataFrame
accidents = pd.concat([pd.read_csv(f, low_memory=False) for f in files], ignore_index=True)

# %%
accidents
# Out:
#        accident_index  accident_year accident_reference  \
# 0       2017010001708           2017          010001708
# 1       2017010009342           2017          010009342
# 2       2017010009344           2017          010009344
# 3       2017010009348           2017          010009348
# 4       2017010009350           2017          010009350
# ...               ...            ...                ...
# 562434  2021991196247           2021          991196247
# 562435  2021991196607           2021          991196607
# 562436  2021991197944           2021          991197944
# 562437  2021991200639           2021          991200639
# 562438  2021991201030           2021          991201030
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 0                    532920.0                196330.0  -0.080107  51.650061
# 1                    526790.0                181970.0  -0.173845  51.522425
# ...

# %%
accidents['local_authority_highway'].unique()
# Out:
# array(['E09000010', 'E09000033', 'E09000030', 'E09000012', 'E09000027',
#        'E09000017', 'E09000003', 'E09000022', 'E09000014', 'E09000009',
#        'E09000028', 'E09000007', 'E09000016', 'E09000032', 'E09000013',
#        'EHEATHROW', 'E09000026', 'E09000002', 'E09000011', 'E09000024',
#        'E09000031', 'E09000006', 'E09000029', 'E09000005', 'E09000019',
#        'E09000008', 'E09000004', 'E09000018', 'E09000025', 'E09000021',
#        'E09000020', 'E09000015', 'E09000023', 'E09000001', 'E10000006',
#        'E10000017', 'E06000008', 'E06000009', 'E08000015', 'E08000012',
#        'E08000014', 'E08000011', 'E08000013', 'E08000010', 'E08000007',
#        'E08000009', 'E08000003', 'E08000006', 'E08000008', 'E08000001',
#        'E08000002', 'E08000005', 'E08000004', 'E06000049', 'E06000007',
#        'E06000050', 'E06000006', 'E08000022', 'E08000021', 'E08000020',
#        'E08000023', 'E06000048', 'E08000024', 'E06000005', 'E06000047',
# ...

# %%
accidents[(accidents['local_authority_highway'] == '-1') & (accidents['accident_year'] == 2018)]
# Out:
#        accident_index  accident_year accident_reference  \
# 204608  2018370256350           2018          370256350
# 204610  2018370258201           2018          370258201
# 204612  2018370260290           2018          370260290
# 204615  2018370260720           2018          370260720
# 204617  2018370260794           2018          370260794
# ...               ...            ...                ...
# 206065  2018370828800           2018          370828800
# 206066  2018370829955           2018          370829955
# 206067  2018370833307           2018          370833307
# 206068  2018370835221           2018          370835221
# 206069  2018370841831           2018          370841831
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 204608               589233.0                257460.0   0.766560  52.182936
# 204610               630021.0                234111.0   1.346445  51.957890
# ...

# %%
accidents[(accidents['police_force'] == 37) & (accidents['accident_year'] == 2018)]
# Out:
#        accident_index  accident_year accident_reference  \
# 204607  2018370256025           2018          370256025
# 204608  2018370256350           2018          370256350
# 204609  2018370258121           2018          370258121
# 204610  2018370258201           2018          370258201
# 204611  2018370259744           2018          370259744
# ...               ...            ...                ...
# 206065  2018370828800           2018          370828800
# 206066  2018370829955           2018          370829955
# 206067  2018370833307           2018          370833307
# 206068  2018370835221           2018          370835221
# 206069  2018370841831           2018          370841831
#
#         location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 204607               603468.0                243203.0   0.965972  52.049866
# 204608               589233.0                257460.0   0.766560  52.182936
# ...

# %%
accidents.isna().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          133
# location_northing_osgr                         133
# longitude                                      143
# latitude                                       143
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...

# %%
accidents.groupby('accident_year').count()
# Out:
#                accident_index  accident_reference  location_easting_osgr  \
# accident_year
# 2017                   129982              129982                 129963
# 2018                   122635              122635                 122580
# 2019                   117536              117536                 117508
# 2020                    91199               91199                  91185
# 2021                   101087              101087                 101070
#
#                location_northing_osgr  longitude  latitude  police_force  \
# accident_year
# 2017                           129963     129953    129953        129982
# 2018                           122580     122580    122580        122635
# 2019                           117508     117508    117508        117536
# 2020                            91185      91185     91185         91199
# 2021                           101070     101070    101070        101087
#
# ...
